# %% [markdown]
# ### CS490/5590 — Quantum Computing Applications in Data Science, AI & Deep Learning
#
# **Mid-Term Examination (Sessions 1 – 8)**
# Time Allowed : **75 minutes**  Total : **50 points**
#
# > **Permitted material**: one double-sided, handwritten 8½ × 11" cheat-sheet.
# > **No calculators, laptops, phones, or additional notes.**
# > All answers must be written in the spaces provided. Show intermediate steps where requested; illegible work will not be graded.
#
# ---
#
# ## **Section A – Multiple Choice (10 × 2 pts = 20 pts)**
#
# *Circle exactly one option for each question.*
#
# 1. Which of the following single-qubit gates is its own inverse **and** maps $|0⟩$ to a superposition state?
# - a. $X$
# - b. $Z$
# - c. $H$
# - d. $S$
#
# 2. The controlled-NOT gate is **not** …
# - a) unitary
# - b) reversible
# - c) its own inverse
# - d) diagonal
#
# 3. In the Deutsch–Jozsa algorithm with an $n$-bit input, the final measurement of all zeroes implies the oracle function is …
# - a) balanced
# - b) constant
# - c) periodic
# - d) parity-dependent
#
# 4. Grover’s optimal number of iterations for one marked item in a list of size $N$ is approximately
# - a) $\sqrt N$
# - b) $\pi\sqrt N/4$
# - c) $N/2$
# - d) $\log_2 N$
#
# 5. A depolarising channel acting on a single qubit with probability $p$ replaces the qubit state with …
# - a) $|0⟩$
# - b) the maximally mixed state
# - c) its orthogonal complement
# - d) a classical bit string
#
# 6. Which Qiskit transpiler optimisation level performs noise-adaptive qubit layout **and** basic gate commuting?
# - a) 0
# - b) 1
# - c) 2
# - d) 3
#
# 7. The Quantum Fourier Transform on $n$ qubits requires exactly …
# -    a) $n$ Hadamards and no controlled gates
# -    b) $n$ controlled-phase gates and no Hadamards
# -    c) $n$ Hadamards and $\tfrac{n(n-1)}2$ controlled-phase gates
# -    d) $2^n$ gates total
#
# 8. In QAOA, the mixer Hamiltonian $H_B = \sum_i X_i$ is used primarily to
# - a) encode the cost function
# - b) initialise the ground state
# - c) explore the search space
# - d) measure the solution
#
# 9. Over-rotating past the optimal angle in Grover’s algorithm causes the success probability to
# - a) stay maximal
# - b) decrease then oscillate
# - c) decrease monotonically to zero
# - d) remain at 50 %
#
# 10. The controlled-$U^{2^k}$ gates in Quantum Phase Estimation encode the unknown phase into
# - a) amplitudes of the eigenstate register
# - b) relative phases of counting qubits
# - c) classical ancilla bits
# - d) measurement basis choice
#
# ---
#
# ## **Section B – Short Derivations / Explanations (4 × 5 pts = 20 pts)**
#
# **B1.** *(Deutsch–Jozsa)* For $n=3$, write the explicit state of the counting register **before** the final Hadamard layer when the oracle is balanced and the input is the uniform superposition produced by $H^{\otimes3}$.  Show your steps.
#
# ---
#
# **B2.** *(Grover depth)* Given $N=16$ database items and one marked solution,
#   a) Compute the optimal integer number of Grover iterations $k_{\text{opt}}$.
#   b) Sketch how the success probability evolves for $k=0,1,\ldots, k_{\text{opt}}+1$.  Label the values on your sketch qualitatively (e.g., “≈1”, “≈0”).
#
# ---
#
# **B3.** *(Noise model)* Derive the Kraus operators for a single-qubit pure dephasing channel that leaves computational-basis populations unchanged but multiplies off-diagonal terms by $e^{-t/T_2}$.  Clearly state the physical meaning of each Kraus operator.
#
# ---
#
# **B4.** *(QAOA cost expectation)* For a ring graph of four vertices with equal weights, write the MaxCut cost Hamiltonian $H_C$ in terms of Pauli $Z$ operators.  Using a depth-$p=1$ QAOA state $|\psi(\beta,\gamma)\rangle$, compute $\langle Z_1 Z_2\rangle$ after applying only the mixer layer $e^{-i\beta H_B}$ (i.e., set $\gamma=0$).  Provide the expression in terms of $\beta$.
#
# ---
#
# ## **Section C – Circuit Trace (1 × 5 pts = 5 pts)**
#
# Consider the 3-qubit circuit below (qubits indexed top→bottom). Work in the computational basis and **do not simplify with global phases**. Show the state vector **just before measurement**.
#
# ```
# q0: |0> ──H─────●───────────┐
#                 │           │
# q1: |0> ──H─────┼────●───X──┼─
#                 │    │      │
# q2: |0> ────────⊕────⊕──────┘
# ```
#
# (The X gate acts on q1.)
#
# ---
#
# ## **Section D – Conceptual Essay (choose ONE, 5 pts)**
#
# Write **one paragraph** (\~6 – 8 sentences).
#
# **D1.** Explain why error-mitigation techniques (e.g., zero-noise extrapolation and read-out calibration) are considered stop-gaps for NISQ devices and discuss what advantages full quantum error *correction* would bring to algorithms like QPE and QAOA.
#
# **or**
#
# **D2.** Discuss how entanglement serves as a computational resource in both teleportation and the construction of quantum feature maps for QSVMs.  Highlight similarities and differences in how entanglement is generated and utilised.
#
# ---
#
# ### End of Exam
#
# *You may detach the formula sheet from your notes if needed. Good luck!*
