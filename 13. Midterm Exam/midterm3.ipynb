# %% [markdown]
# ### CS490/5590 — Quantum Computing Applications in Data Science, AI & Deep Learning
#
# **Mid-Term Examination #3 (Sessions 1 – 8)**
# Time Allowed : **75 minutes**  Total : **50 points**
#
# > **What you may use:** one handmade, double-sided cheat-sheet (8½ × 11″).
# > **What you may **not** use:** electronic devices, printed notes, books, internet.
# > Work must be legible and logically organised; unsupported answers earn no credit.
#
# ---
#
# ## **Section A – Multiple Choice** (10 × 2 pts = 20 pts)
#
# Circle **one** answer.
#
# 1. A single-qubit **S** gate corresponds to a rotation by
# - a) π/4 about X
# - b) π/2 about Z
# - c) π/2 about Y
# - d) π about Z
#
# 2. Which pair of gates **anticommute**?
# - a) X and Z
# - b) Z and S
# - c) H and T
# - d) CNOT and SWAP
#
# 3. The **swap-test** measures the overlap $|\langle\psi|\phi\rangle|^2$ using
# - a) a controlled-SWAP and a Hadamard
# - b) two CNOTs and a Z gate
# - c) a Toffoli
# - d) only single-qubit rotations
#
# 4. In a balanced 4-bit Deutsch–Jozsa oracle, the amplitude of $|0000⟩$ after the first Hadamard layer and oracle call is
# - a) 0
# - b) 1/16
# - c) 1/4
# - d) 1
#
# 5. The probability of remaining in the **logical $|1_L⟩$** after one amplitude-damping event with rate γ is
# - a) $e^{-γ}$
# - b) $1-γ$
# - c) $1-γ/2$
# - d) independent of γ
#
# 6. A **diffusion** operator can be built from Hadamards, X gates, and one multi-controlled …
# - a) X
# - b) Z
# - c) Y
# - d) swap
#
# 7. Qiskit’s **routing** pass inserts SWAPs to satisfy
# - a) noisy qubit ranking
# - b) basis-gate set
# - c) hardware coupling map
# - d) read-out calibration
#
# 8. Controlled-$U^{2^k}$ in QPE requires **exactly** $2^k$ calls to $U$ when
# - a) $U$ is diagonal
# - b) no ancillas are available
# - c) controlled powers are not pre-compiled
# - d) the eigenvalue is unknown
#
# 9. In QAOA with depth $p$, the number of tunable parameters in the standard formulation is
# - a) $p$
# - b) $2p$
# - c) $p^2$
# - d) independent of $p$
#
# 10. **Pauli twirling** converts coherent errors into ­–
# - a) stochastic Pauli errors
# - b) thermal relaxation
# - c) read-out flips
# - d) deterministic over-rotations
#
# ---
#
# ## **Section B – Short Derivations / Calculations** (4 × 5 pts = 20 pts)
#
# **B1.  (Gate algebra)**
# Show that $HZH = X$.  Write the matrices explicitly and perform the multiplication.
#
# ---
#
# **B2.  (Grover amplitude)**
# For $N = 8$ and a single marked item, compute the amplitude of the marked basis state **after zero, one, and two** Grover iterations (ideal noiseless circuit).  Express each amplitude in exact trig form (e.g., $\sin(\theta)$, $\cos(\theta)$).
#
# ---
#
# **B3.  (Amplitude-damping Kraus set)**
# Give the Kraus operators $\{K_0, K_1\}$ for a single-qubit amplitude-damping channel with decay probability $p$.  Verify that they satisfy $\sum_i K_i^\dagger K_i = I$.
#
# ---
#
# **B4.  (Deutsch–Jozsa state)**
# For $n = 2$ and a **balanced** oracle defined by $f(00)=f(01)=0,\;f(10)=f(11)=1$, derive the full 4-component state vector **immediately after** oracle application (before the second Hadamard layer).  Use the $|x⟩|b⟩$ bit-flip oracle with ancilla initialised to $|1⟩$.
#
# ---
#
# ## **Section C – Circuit Trace** (1 × 5 pts = 5 pts)
#
# Analyse this three-qubit circuit (top wire = q0).  Compute the final state vector and the probability of measuring $|101⟩$.
#
# ```
# q0: |0> ──H──────●───────────────
#                  │
# q1: |0> ─────────⊕───Ry(π/2)───●─
#                              │
# q2: |0> ───────────────X─────⊕───
# ```
#
# ---
#
# ## **Section D – Conceptual Essay  (choose ONE)** (5 pts)
#
# **D1.** Explain the primary **sources of barren plateaus** in variational algorithms. Compare how a problem-inspired ansatz and a hardware-efficient ansatz mitigate or exacerbate this phenomenon.
#
# **– OR –**
#
# **D2.** Describe how **error-mitigation** techniques (zero-noise extrapolation, dynamical decoupling, read-out calibration) are combined in practice to improve Grover’s algorithm on NISQ hardware. Highlight the trade-off between additional sampling cost and fidelity gain.
#
# ---
#
# ### **End of Examination**
#
# *Check that every page includes your name and student ID.  Hand in all pages including scratch work.*
